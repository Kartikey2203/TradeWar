# %%
import pandas as pd
import numpy as np

# pd.set_option("display.max_columns", None)
# pd.set_option("display.max_rows", 20)

# %%
trade_total = pd.read_csv("../data/raw/Trade_total.csv")

# %%
trade_total.head()
# Out:
#   typeCode  freqCode  refPeriodId  refYear  refMonth  period reporterCode  \
# C        A  20170101         2017       52      2017     842          USA
# C        A  20170101         2017       52      2017     842          USA
# C        A  20170101         2017       52      2017     842          USA
# C        A  20170101         2017       52      2017     842          USA
# C        A  20170101         2017       52      2017     842          USA
#
#   reporterISO reporterDesc flowCode  ...  netWgt isNetWgtEstimated grossWgt  \
# C         USA            X   Export  ...   False                 0    False
# C         USA            M   Import  ...   False                 0    False
# C         USA            X   Export  ...   False                 0    False
# C         USA            M   Import  ...   False                 0    False
# C         USA            X   Export  ...   False                 0    False
#
#    isGrossWgtEstimated   cifvalue   fobvalue primaryValue  \
# ...

# %%
trade_total.primaryValue.max()
# Out:
# 6

# %%
trade_total.columns[trade_total.columns.duplicated()]
# Out:
# Index([], dtype='object')

# %%
for i, col in enumerate(trade_total.columns):
    print(i, col)
# Out:
# 0 typeCode
# 1 freqCode
# 2 refPeriodId
# 3 refYear
# 4 refMonth
# 5 period
# 6 reporterCode
# 7 reporterISO
# 8 reporterDesc
# 9 flowCode
# 10 flowDesc
# 11 partnerCode
# 12 partnerISO
# 13 partnerDesc
# 14 partner2Code
# 15 partner2ISO
# 16 partner2Desc
# 17 classificationCode
# 18 classificationSearchCode
# 19 isOriginalClassification
# 20 cmdCode
# 21 cmdDesc
# 22 aggrLevel
# 23 isLeaf
# 24 customsCode
# 25 customsDesc
# 26 mosCode
# 27 motCode
# 28 motDesc
# 29 qtyUnitCode
# 30 qtyUnitAbbr
# 31 qty
# 32 isQtyEstimated
# 33 altQtyUnitCode
# 34 altQtyUnitAbbr
# 35 altQty
# 36 isAltQtyEstimated
# 37 netWgt
# 38 isNetWgtEstimated
# 39 grossWgt
# 40 isGrossWgtEstimated
# 41 cifvalue
# 42 fobvalue
# 43 primaryValue
# 44 legacyEstimationFlag
# 45 isReported
# 46 isAggregate

# %%
trade_total["primaryValue"].head(10)
# Out:
# C    0
# C    0
# C    0
# C    0
# C    0
# C    0
# C    0
# C    0
# C    0
# C    4
# Name: primaryValue, dtype: int64

# %%
print(trade_total.columns.duplicated().sum())
# Out:
# 0

# %%
trade_total.loc[:, "primaryValue"].head(10)
# Out:
# C    0
# C    0
# C    0
# C    0
# C    0
# C    0
# C    0
# C    0
# C    0
# C    4
# Name: primaryValue, dtype: int64
