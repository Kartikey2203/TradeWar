# %%
import pandas as pd
import numpy as np

# %%
df = pd.read_csv("Trade_total.csv", index_col=0)

# %%
df = pd.read_csv("Trade_total.csv")

# drop the last column label (it has no corresponding data)
df = df.iloc[:, :-1]

# %%
df = pd.read_csv("Trade_total.csv", header=None, skiprows=1)  # read raw, no header guessing
correct_headers = open("Trade_total.csv").readline().strip().split(",")[:-1]  # drop extra label
df = df.iloc[:, :len(correct_headers)]
df.columns = correct_headers

# %%
df
# Out:
#     typeCode freqCode  refPeriodId  refYear  refMonth  period  reporterCode  \
# 0          C        A     20170101     2017        52    2017           842
# 1          C        A     20170101     2017        52    2017           842
# 2          C        A     20170101     2017        52    2017           842
# 3          C        A     20170101     2017        52    2017           842
# 4          C        A     20170101     2017        52    2017           842
# ..       ...      ...          ...      ...       ...     ...           ...
# 163        C        A     20250101     2025        52    2025           842
# 164        C        A     20250101     2025        52    2025           842
# 165        C        A     20250101     2025        52    2025           842
# 166        C        A     20250101     2025        52    2025           842
# 167        C        A     20250101     2025        52    2025           842
#
# ...

# %%
with open("Trade_total.csv", "r", encoding="utf-8") as f:
    header = f.readline().strip().split(",")
    row = f.readline().strip().split(",")

print("Header:", len(header))
print("Row:", len(row))

for i, value in enumerate(row):
    print(i, value)
# Out:
# Header: 47
# Row: 49
# 0 "C"
# 1 "A"
# 2 "20170101"
# 3 "2017"
# 4 "52"
# 5 "2017"
# 6 "842"
# 7 "USA"
# 8 "USA"
# 9 "X"
# 10 "Export"
# 11 "156"
# 12 "CHN"
# 13 "China"
# 14 "0"
# 15 "W00"
# 16 "World"
# 17 "H5"
# 18 "HS"
# 19 "true"
# 20 "0203"
# 21 "Meat of swine; fresh
# 22  chilled or frozen"
# 23 "4"
# 24 "false"
# 25 "C00"
# 26 "TOTAL CPC"
# 27 "0"
# 28 "0"
# 29 "TOTAL MOT"
# 30 "8"
# 31 "kg"
# 32 "127451413"
# 33 "false"
# 34 "-1"
# 35 "N/A"
# 36 "0"
# 37 "false"
# 38 "127451413"
# 39 "false"
# 40 "0"
# 41 "false"
# 42 "0"
# 43 "237191006"
# 44 "237191006"
# 45 "0"
# 46 "false"
# 47 "true"
# 48
